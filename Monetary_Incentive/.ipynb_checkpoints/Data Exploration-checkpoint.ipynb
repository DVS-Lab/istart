# %%
#Import the Libraries
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
import pandas as pd
import os
from natsort import natsorted

# %%
#Make a list of the files
Mat_Beh_dir='data'
ML_EvFiles_list=natsorted([os.path.join(root,f) for root,dirs,files in os.walk(Mat_Beh_dir) for f in files if 'run' in f]
ML_EvFiles_list
# Out:
# ['data/sub-1302/run-1_output.mat',
#  'data/sub-1999/run-1_output.mat',
#  'data/sub-1999/run-2_output.mat',
#  'data/sub-1300/run-1_output.mat',
#  'data/sub-1300/run-2_output.mat',
#  'data/sub-1007/run-1_output.mat',
#  'data/sub-1007/run-2_output.mat',
#  'data/sub-1244/run-1_output.mat',
#  'data/sub-1244/run-2_output.mat',
#  'data/sub-3166/run-1_output.mat',
#  'data/sub-1242/run-1_output.mat',
#  'data/sub-1019/run-1_output.mat',
#  'data/sub-1019/run-2_output.mat',
#  'data/sub-1253/run-1_output.mat',
#  'data/sub-1253/run-2_output.mat',
#  'data/sub-3164/run-1_output.mat',
#  'data/sub-3122/run-1_output.mat',
#  'data/sub-1294/run-1_output.mat',
#  'data/sub-1010/run-1_output.mat',
#  'data/sub-1010/run-2_output.mat',
#  'data/sub-1301/run-1_output.mat',
#  'data/sub-1301/run-2_output.mat',
#  'data/sub-1009/run-1_output.mat',
#  'data/sub-1009/run-2_output.mat',
#  'data/sub-3101/run-1_output.mat',
#  'data/sub-3176/run-1_output.mat',
#  'data/sub-3116/run-1_output.mat',
#  'data/sub-1243/run-1_output.mat',
#  'data/sub-1243/run-2_output.mat',
#  'data/sub-3173/run-1_output.mat',
#  'data/sub-3152/run-1_output.mat',
#  'data/sub-1249/run-1_output.mat',
#  'data/sub-1249/run-2_output.mat',
#  'data/sub-1276/run-1_output.mat',
#  'data/sub-1247/run-1_output.mat',
#  'data/sub-1247/run-2_output.mat',
#  'data/sub-3140/run-1_output.mat',
#  'data/sub-1012/run-1_output.mat',
#  'data/sub-1012/run-2_output.mat',
#  'data/sub-3125/run-1_output.mat',
#  'data/sub-1255/run-1_output.mat',
#  'data/sub-1255/run-2_output.mat',
#  'data/sub-1013/run-1_output.mat',
#  'data/sub-1013/run-2_output.mat',
#  'data/sub-1021/run-1_output.mat',
#  'data/sub-1021/run-2_output.mat',
#  'data/sub-1245/run-1_output.mat',
#  'data/sub-1245/run-2_output.mat',
#  'data/sub-3143/run-1_output.mat',
#  'data/sub-1285/run-2_output.mat',
#  'data/sub-1011/run-1_output.mat',
#  'data/sub-1011/run-2_output.mat',
#  'data/sub-1286/run-1_output.mat',
#  'data/sub-1015/run-1_output.mat',
#  'data/sub-1015/run-2_output.mat',
#  'data/sub-1282/run-1_output.mat',
#  'data/sub-3167/run-1_output.mat',
#  'data/sub-3170/run-1_output.mat',
#  'data/sub-1016/run-1_output.mat',
#  'data/sub-1016/run-2_output.mat',
#  'data/sub-999/run-1_output.mat',
#  'data/sub-999/run-3_output.mat',
#  'data/sub-1248/run-1_output.mat',
#  'data/sub-1248/run-2_output.mat']

# %%
 
mat = loadmat('output_737776.598.mat')  # load mat-file
mdata = mat['output']  # variable in mat file
mdtype = mdata.dtype  # dtypes of structures are "unsized objects"
# * SciiencPy reads in structures as structured NumPy arrays of dtype object
# * The size of the array is the size of the structure array, not the number
#   elements in any particular field. The shape defaults to 2-dimensional.
# * For convene make a dictionary of the data using the names from dtypes
# * Since the structure has only one element, but is 2-D, index it at [0, 0]
ndata = {n: mdata[n][0, 0] for n in mdtype.names}
# Reconstruct the columns of the data table from just the time series
# Use the number of intervals to test if a field is a column or metadata
columns = [n for n in ndata]
# now make a data frame, setting the time stamps as the index
df = pd.DataFrame(np.transpose(np.concatenate([ndata[c] for c in columns])),
                  columns=columns)

# %%
df
# Out:
#     outcome  trial_starts  target_starts        RT    thresh
# 0       0.0      4.010762       8.022571  0.354283  0.276950
# 1       0.0     11.044226      15.054782  0.297043  0.455986
# 2       1.0     20.671578      23.681881  0.335001  0.473628
# 3       1.0     27.898481      29.909041  0.376822  0.364263
# 4       1.0     36.328354      39.340353  0.289026  0.467346
# 5       0.0     44.756756      46.766727  0.482710  0.404411
# 6       1.0     50.781841      53.791512  0.272044  0.344580
# 7       1.0     56.807222      60.817835  0.431737  0.387870
# 8       1.0     64.033129      68.043057  0.206402  0.347524
# 9       1.0     72.459319      76.469541  0.286123  0.465934
# 10      0.0     86.885678      89.896494  0.592281  0.400994
# 11      0.0     95.313442      98.323901  0.414722  0.425586
# 12      0.0    104.941554     108.952369  0.429922  0.497372
# 13      0.0    118.168795     120.178997  0.414416  0.361245
# 14      1.0    125.395661     128.406509  0.415875  0.464776
# 15      1.0    142.223411     145.233151  0.016176  0.424161
# 16      1.0    148.249642     150.259664  0.240468  0.429639
# 17      1.0    154.275646     158.286305  0.312781  0.409393
# 18      1.0    161.502184     165.512551  0.368612  0.434406
# 19      1.0    168.728447     170.738636  0.413606  0.435974
# 20      1.0    183.154971     186.165061  0.327171  0.388447
# 21      1.0    190.380858     192.391024  0.109049  0.424061
# 22      0.0    197.607008     199.617155  0.846985  0.388447
# 23      1.0    212.034341     214.044461  0.311653  0.355228
# 24      0.0    221.660114     224.670381  0.502599  0.376440
# 25      1.0    238.487178     242.497418  0.320541  0.373797
# 26      1.0    245.712582     249.722659  0.313143  0.376143
# 27      0.0    252.938358     254.948766  0.549946  0.467295
# 28      1.0    258.964423     260.975185  0.313568  0.472758
# 29      1.0    267.392028     270.403210  0.323497  0.368567
# 30      0.0    274.618526     276.629255  0.503484  0.423518
# 31      1.0    280.645212     282.655030  0.293709  0.413490
# 32      1.0    298.671958     302.682350  0.067294  0.422099
# 33      1.0    305.697504     309.707877  0.041636  0.403746
# 34      0.0    318.924191     320.934762  0.424984  0.432519
# 35      1.0    324.950706     326.960316  0.289276  0.304737
# 36      1.0    334.576671     336.586360  0.296338  0.306152
# 37      0.0    341.802713     344.812744  0.566696  0.306152
# 38      1.0    351.429235     355.439292  0.274187  0.447353
# 39      1.0    358.454209     362.465118  0.276620  0.432582
# 40      0.0    372.882662     375.892645  0.356706  0.325736
# 41      0.0    384.909216     387.919452  0.495845  0.511823
# 42      0.0    392.134647     395.144572  0.354624  0.339470
# 43      1.0    400.560045     404.570850  0.349423  0.434000
# 44      1.0    408.986429     411.997151  0.324068  0.413410
# 45      1.0    416.212793     418.222553  0.026585  0.434000
# 46      1.0    422.238268     425.248225  0.001083  0.488663
# 47      0.0    433.065175     437.075765  0.424176  0.374259
# 48      0.0    440.091061     442.100597  0.648526  0.416150
# 49      1.0    450.916843     454.927744  0.071212  0.393406
