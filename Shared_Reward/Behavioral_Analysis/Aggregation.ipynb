# %%
import os
import numpy as np
import pandas as pd
import re

os.chdir('.')

def listdir():
    for root, dirs, files in os.walk("."):
        for filename in files:
            print(filename)

# %%
data = pd.read_csv('SR_PartnerRatings_PS.csv', header = 0)
data
# Out:
#      TrialNumber  Partner  Trait  ran  order  Rating   sub
# 0              1        3      0    1      0       5  1294
# 1              2        2      0    1      1       0  1294
# 2              3        1      0    1      2       0  1294
# 3              4        3      1    1      3      -2  1294
# 4              5        2      1    1      4       0  1294
# ..           ...      ...    ...  ...    ...     ...   ...
# 265            2        2      0    1      1      -2  1001
# 266            3        1      0    1      2       5  1001
# 267            4        3      1    1      3       5  1001
# 268            5        2      1    1      4       0  1001
# 269            6        1      1    1      5       4  1001
#
# [270 rows x 7 columns]

# %%
Trait = {0:'Win', 1:'Lose'}
Partner = {3:'Friend',2:'Stranger',1:'Comp'}

# %%
collapsed = {}
for index, row in data.iterrows():
    if(not row['sub'] in collapsed):
        collapsed[row['sub']] = {}
    column_name = Trait[row['Trait']] + '-' + Partner[row['Partner']]
    collapsed[row['sub']][column_name] = row['Rating']
# Out:
# {1294: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': -2,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1002: {'Win-Friend': 4,
#   'Win-Stranger': 2,
#   'Win-Comp': 0,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 0},
#  1302: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -5,
#   'Lose-Friend': -2,
#   'Lose-Stranger': -3,
#   'Lose-Comp': -5},
#  1244: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 0,
#   'Lose-Friend': -2,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3164: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -2,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -2},
#  1015: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 0,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -3,
#   'Lose-Comp': 0},
#  1009: {'Win-Friend': 5,
#   'Win-Stranger': 4,
#   'Win-Comp': 4,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -4,
#   'Lose-Comp': -4},
#  1006: {'Win-Friend': 3,
#   'Win-Stranger': 2,
#   'Win-Comp': 5,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -1,
#   'Lose-Comp': -2},
#  1282: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 1,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -2,
#   'Lose-Comp': 0},
#  3122: {'Win-Friend': 4,
#   'Win-Stranger': 3,
#   'Win-Comp': 0,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -4,
#   'Lose-Comp': -1},
#  1276: {'Win-Friend': 3,
#   'Win-Stranger': -4,
#   'Win-Comp': 2,
#   'Lose-Friend': -4,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -2},
#  3176: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 2,
#   'Lose-Friend': -1,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -3},
#  1243: {'Win-Friend': 2,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': -2,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 0},
#  1012: {'Win-Friend': 3,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': -3,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3116: {'Win-Friend': 5,
#   'Win-Stranger': 1,
#   'Win-Comp': 0,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 0},
#  3143: {'Win-Friend': 4,
#   'Win-Stranger': -2,
#   'Win-Comp': 3,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -2},
#  1016: {'Win-Friend': 0,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3190: {'Win-Friend': 5,
#   'Win-Stranger': -1,
#   'Win-Comp': 4,
#   'Lose-Friend': 2,
#   'Lose-Stranger': -2,
#   'Lose-Comp': 2},
#  3186: {'Win-Friend': 4,
#   'Win-Stranger': 0,
#   'Win-Comp': -2,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 4},
#  3166: {'Win-Friend': 4,
#   'Win-Stranger': 1,
#   'Win-Comp': 0,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -3,
#   'Lose-Comp': -1},
#  3125: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -5,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1021: {'Win-Friend': 1,
#   'Win-Stranger': 1,
#   'Win-Comp': 0,
#   'Lose-Friend': 1,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3167: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 2,
#   'Lose-Friend': -2,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -3},
#  1300: {'Win-Friend': 3,
#   'Win-Stranger': 5,
#   'Win-Comp': 0,
#   'Lose-Friend': -1,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1301: {'Win-Friend': -1,
#   'Win-Stranger': -2,
#   'Win-Comp': 3,
#   'Lose-Friend': -3,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3189: {'Win-Friend': 3,
#   'Win-Stranger': 2,
#   'Win-Comp': 1,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -1},
#  1007: {'Win-Friend': 4,
#   'Win-Stranger': 4,
#   'Win-Comp': 3,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1011: {'Win-Friend': 5,
#   'Win-Stranger': 5,
#   'Win-Comp': 2,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -5},
#  1013: {'Win-Friend': 5,
#   'Win-Stranger': -3,
#   'Win-Comp': 2,
#   'Lose-Friend': -4,
#   'Lose-Stranger': 1,
#   'Lose-Comp': -2},
#  3173: {'Win-Friend': 5,
#   'Win-Stranger': -2,
#   'Win-Comp': -4,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1242: {'Win-Friend': 0,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1249: {'Win-Friend': 5,
#   'Win-Stranger': 5,
#   'Win-Comp': 4,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -4},
#  1019: {'Win-Friend': 5,
#   'Win-Stranger': 2,
#   'Win-Comp': 0,
#   'Lose-Friend': -3,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1248: {'Win-Friend': 1,
#   'Win-Stranger': 0,
#   'Win-Comp': -5,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -5},
#  3170: {'Win-Friend': 5,
#   'Win-Stranger': 4,
#   'Win-Comp': 3,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1286: {'Win-Friend': 4,
#   'Win-Stranger': 2,
#   'Win-Comp': 3,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -3},
#  3152: {'Win-Friend': 5,
#   'Win-Stranger': 2,
#   'Win-Comp': 3,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -1,
#   'Lose-Comp': -3},
#  1010: {'Win-Friend': 1,
#   'Win-Stranger': -2,
#   'Win-Comp': -5,
#   'Lose-Friend': 2,
#   'Lose-Stranger': -3,
#   'Lose-Comp': -5},
#  1255: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -1,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -2},
#  3140: {'Win-Friend': 5,
#   'Win-Stranger': 2,
#   'Win-Comp': -1,
#   'Lose-Friend': -2,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -1},
#  1251: {'Win-Friend': 2,
#   'Win-Stranger': 0,
#   'Win-Comp': 1,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -2},
#  1001: {'Win-Friend': 5,
#   'Win-Stranger': -2,
#   'Win-Comp': 5,
#   'Lose-Friend': 5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 4}}

# %%
#PR = Partner Ratings from post-scan task
PR = pd.DataFrame(collapsed).T
PR = PR.reset_index().rename(columns = {'index':'sub'})
PR.to_csv('SR_PartnerRatings.csv',index=False)
pd.read_csv('SR_PartnerRatings.csv')
# Out:
#      sub  Win-Friend  Win-Stranger  Win-Comp  Lose-Friend  Lose-Stranger  \
# 0   1294           5             0         0           -2              0
# 1   1002           4             2         0           -3             -1
# 2   1302           5             0        -5           -2             -3
# 3   1244           5             3         0           -2              0
# 4   3164           5             0        -2           -4             -5
# 5   1015           5             3         0           -5             -3
# 6   1009           5             4         4           -5             -4
# 7   1006           3             2         5           -4             -1
# 8   1282           5             3         1           -4             -2
# 9   3122           4             3         0           -5             -4
# 10  1276           3            -4         2           -4              0
# 11  3176           5             3         2           -1             -2
# 12  1243           2             0         0           -2             -1
# 13  1012           3             0         0           -3              0
# 14  3116           5             1         0           -4             -1
# 15  3143           4            -2         3           -5             -2
# 16  1016           0             0         0            0              0
# 17  3190           5            -1         4            2             -2
# 18  3186           4             0        -2           -3             -1
# 19  3166           4             1         0           -5             -3
# 20  3125           5             0        -5           -5              0
# 21  1021           1             1         0            1              0
# 22  3167           5             3         2           -2             -5
# 23  1300           3             5         0           -1              0
# 24  1301          -1            -2         3           -3              0
# 25  3189           3             2         1           -4             -2
# 26  1007           4             4         3            0              0
# 27  1011           5             5         2           -5             -5
# 28  1013           5            -3         2           -4              1
# 29  3173           5            -2        -4           -5              0
# 30  1242           0             0         0            0              0
# 31  1249           5             5         4           -5             -5
# 32  1019           5             2         0           -3              0
# 33  1248           1             0        -5           -3             -5
# 34  3170           5             4         3           -5              0
# 35  1286           4             2         3           -3             -2
# 36  3152           5             2         3           -5             -1
# 37  1010           1            -2        -5            2             -3
# 38  1255           5             0        -1           -5              0
# 39  3140           5             2        -1           -2              0
# 40  1251           2             0         1            0              0
# 41  1001           5            -2         5            5              0
#
#     Lose-Comp
# 0           0
# 1           0
# 2          -5
# 3           0
# 4          -2
# 5           0
# 6          -4
# 7          -2
# 8           0
# 9          -1
# 10         -2
# 11         -3
# 12          0
# 13          0
# 14          0
# 15         -2
# 16          0
# 17          2
# 18          4
# 19         -1
# 20          0
# 21          0
# 22         -3
# 23          0
# 24          0
# 25         -1
# 26          0
# 27         -5
# 28         -2
# 29          0
# 30          0
# 31         -4
# 32          0
# 33         -5
# 34          0
# 35         -3
# 36         -3
# 37         -5
# 38         -2
# 39         -1
# 40         -2
# 41          4

# %%
#RC = REDCap data
RC = pd.read_csv('SR_REDCap_data.csv').rename(columns = {'participant_id':'sub', 'ios_p':'closeness_rating'})
#RS = Reward Sensitivity scores
RS = pd.read_csv('Reward_Sensitivity.csv').rename(columns = {'RealID':'sub'})
#ASRD = All Shared Reward Data
ASRD = RS.merge(PR, on = 'sub', how = 'right').sort_values('sub', ascending = True, ignore_index = True)
ASRD = ASRD.merge(RC, on = 'sub', how = 'left').sort_values('sub', ascending = True, ignore_index = True)
ASRD.drop('redcap_event_name', axis = 'columns').to_csv('AllSharedRewardData.csv', index = False)
pd.read_csv('AllSharedRewardData.csv')
# Out:
#      sub  gender     SPSRWD  BISBAS_BAS        PC1  Win-Friend  Win-Stranger  \
# 0   1001       1   7.000000   44.000000   0.748619           5            -2
# 1   1002       2  15.000000   35.000000  -1.338732           4             2
# 2   1006       2  12.000000   37.000000  -1.633791           3             2
# 3   1006       2  12.000000   37.000000  -1.633791           3             2
# 4   1007       1  14.000000   37.000000  -0.391931           4             4
# 5   1009       1  12.000000   40.000000   0.717807           5             4
# 6   1010       2  11.000000   37.000000  -2.254721           1            -2
# 7   1011       2  14.000000   39.000000   1.175801           5             5
# 8   1012       1   5.000000   33.000000  -9.115766           3             0
# 9   1013       1  16.000000   41.000000   3.985393           5            -3
# 10  1015       1   9.000000   35.000000  -5.064313           5             3
# 11  1016       1  15.000000   40.000000   2.580597           0             0
# 12  1019       1  15.000000   39.000000   1.796731           5             2
# 13  1021       1  11.000000   37.000000  -2.254721           1             1
# 14  1242       1  14.000000   40.000000   1.959667           0             0
# 15  1243       1  11.000000   35.000000  -3.822453           2             0
# 16  1244       1  15.000000   48.000000   8.851524           5             3
# 17  1248       2  14.000000   39.000000   1.175801           1             0
# 18  1249       1  13.000000   40.000000   1.338737           5             5
# 19  1251       2   8.000000   24.916667 -13.589224           2             0
# 20  1255       1  11.000000   38.000000  -1.470855           5             0
# 21  1276       1  10.000000   36.000000  -3.659517           3            -4
# 22  1282       1  16.000000   41.000000   3.985393           5             3
# 23  1286       1  12.000000   38.000000  -0.849925           4             2
# 24  1294       1   9.000000   37.000000  -3.496582           5             0
# 25  1300       1   9.000000   33.000000  -6.632045           3             5
# 26  1301       1   8.000000   38.000000  -3.333646          -1            -2
# 27  1302       1  20.000000   47.000000  11.172309           5             0
# 28  3116       1  12.000000   41.000000   1.501672           5             1
# 29  3122       1  16.000000   40.000000   3.201527           4             3
# 30  3125       2  18.000000   44.000000   7.578851           5             0
# 31  3140       1  11.000000   37.000000  -2.254721           5             2
# 32  3143       1  13.000000   37.000000  -1.012861           4            -2
# 33  3152       1  16.000000   42.000000   4.769259           5             2
# 34  3164       2  20.000000   51.000000  14.307773           5             0
# 35  3166       1   7.000000   36.000000  -5.522308           4             1
# 36  3167       1   9.000000   37.000000  -3.496582           5             3
# 37  3170       1   9.000000   32.000000  -7.415911           5             4
# 38  3173       2  14.000000   43.000000   4.311264           5            -2
# 39  3176       1   8.347826   36.000000  -4.685402           5             3
# 40  3186       1  21.000000   49.000000  13.360971           4             0
# 41  3189       2  12.000000   37.000000  -1.633791           3             2
# 42  3190       1  14.000000   43.000000   4.311264           5            -1
#
#     Win-Comp  Lose-Friend  Lose-Stranger  Lose-Comp  screen_age  \
# 0          5            5              0          4         NaN
# 1          0           -3             -1          0         NaN
# 2          5           -4             -1         -2         NaN
# 3          5           -4             -1         -2         NaN
# 4          3            0              0          0   21.235207
# 5          4           -5             -4         -4   20.203016
# 6         -5            2             -3         -5   22.215377
# 7          2           -5             -5         -5   21.979917
# 8          0           -3              0          0   22.064793
# 9          2           -4              1         -2   18.579551
# 10         0           -5             -3          0   21.552918
# 11         0            0              0          0   22.138716
# 12         0           -3              0          0   18.234461
# 13         0            1              0          0   21.196876
# 14         0            0              0          0   20.033266
# 15         0           -2             -1          0   24.641049
# 16         0           -2              0          0   26.281055
# 17        -5           -3             -5         -5   23.523983
# 18         4           -5             -5         -4   19.359626
# 19         1            0              0         -2   21.884091
# 20        -1           -5              0         -2   19.871729
# 21         2           -4              0         -2   21.005223
# 22         1           -4             -2          0   20.326108
# 23         3           -3             -2         -3   22.683445
# 24         0           -2              0          0   21.711603
# 25         0           -1              0          0   20.386341
# 26         3           -3              0          0   23.444584
# 27        -5           -2             -3         -5   23.020322
# 28         0           -4             -1          0   20.123617
# 29         0           -5             -4         -1   20.840948
# 30        -5           -5              0          0   21.766361
# 31        -1           -2              0         -1   23.077818
# 32         3           -5             -2         -2   20.958678
# 33         3           -5             -1         -3   22.573929
# 34        -2           -4             -5         -2   20.755959
# 35         0           -5             -3         -1   21.478766
# 36         2           -2             -5         -3   21.837432
# 37         3           -5              0          0   19.781264
# 38        -4           -5              0          0   18.483496
# 39         2           -1             -2         -3   19.321410
# 40        -2           -3             -1          4   18.551944
# 41         1           -4             -2         -1   23.439222
# 42         4            2             -2          2   19.718292
#
#     closeness_rating
# 0                5.0
# 1                5.0
# 2                5.0
# 3                5.0
# 4                5.0
# 5                6.0
# 6                6.0
# 7                5.0
# 8                5.0
# 9                4.0
# 10               4.0
# 11               3.0
# 12               3.0
# 13               2.0
# 14               2.0
# 15               3.0
# 16               2.0
# 17               5.0
# 18               7.0
# 19               5.0
# 20               4.0
# 21               2.0
# 22               5.0
# 23               5.0
# 24               5.0
# 25               6.0
# 26               4.0
# 27               4.0
# 28               4.0
# 29               7.0
# 30               7.0
# 31               7.0
# 32               6.0
# 33               6.0
# 34               6.0
# 35               4.0
# 36               4.0
# 37               7.0
# 38               3.0
# 39               6.0
# 40               5.0
# 41               4.0
# 42               4.0
