# %%
import pandas as pd
import scipy.stats as stats
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sms
import os
import inspect

# %%
os.listdir('.')
# Out:
# ['GitHub - Shortcut.lnk',
#  'social_reward_c',
#  'Shared_Reward',
#  'UGDG',
#  '.gitignore',
#  'ITC',
#  'button_test',
#  'Reward_Sensitivity.csv',
#  'genSharedRewardBlocks.m',
#  'risk_amb',
#  'Mock_Scan',
#  '.git',
#  'Monetary_Incentive',
#  'test.txt',
#  'README.md']

# %%
fname='istart/Reward_Sensitivity.csv'
df=pd.read_csv(fname)
print(type(df))
print(type(pd.read_csv))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'function'>

# %%
cormat=df.corr()
display(cormat)
fig = plt.figure(figsize=(12, 8))
sms.heatmap(cormat,cmap='vlag',vmin=-1)
# Out:
#                         RealID    gender   spsrq_1   spsrq_2   spsrq_3  \
# RealID                1.000000  0.018243  0.027498  0.002725  0.304314
# gender                0.018243  1.000000 -0.127704 -0.005995 -0.101478
# spsrq_1               0.027498 -0.127704  1.000000  0.014149  0.085045
# spsrq_2               0.002725 -0.005995  0.014149  1.000000 -0.110993
# spsrq_3               0.304314 -0.101478  0.085045 -0.110993  1.000000
# ...                        ...       ...       ...       ...       ...
# bisbas_20            -0.016200  0.038487  0.058878  0.094131  0.145067
# SPSRWD               -0.041490  0.207568 -0.245142  0.295153 -0.055808
# BISBAS_BAS            0.045425 -0.008792 -0.161618  0.324326  0.026565
# BISBAS_BAS_Quintiles -0.023076  0.039161 -0.142898  0.312337 -0.032182
# SPSRWD_Quintiles     -0.052482  0.269254 -0.211937  0.283232 -0.047915
#
#                        spsrq_4   spsrq_5   spsrq_6   spsrq_7   spsrq_8  ...  \
# RealID               -0.199178  0.105557 -0.158575  0.078412  0.140550  ...
# gender                0.014449 -0.108839  0.047678 -0.041453  0.159614  ...
# spsrq_1              -0.049431  0.313654 -0.061950  0.119181 -0.326385  ...
# spsrq_2               0.037257  0.137973 -0.137578  0.044668 -0.048070  ...
# spsrq_3               0.020565  0.264441  0.067862  0.425781  0.045027  ...
# ...                        ...       ...       ...       ...       ...  ...
# bisbas_20             0.155032  0.055170 -0.057553  0.039123 -0.038187  ...
# SPSRWD                0.212628 -0.122345  0.144888 -0.117014  0.311568  ...
# BISBAS_BAS            0.084706 -0.145539  0.157408  0.029969  0.095581  ...
# BISBAS_BAS_Quintiles  0.088841 -0.173372  0.183534 -0.019403  0.030853  ...
# SPSRWD_Quintiles      0.230968 -0.125061  0.155290 -0.084454  0.291380  ...
#
#                       bisbas_14  bisbas_15  bisbas_17  bisbas_18  bisbas_19  \
# RealID                 0.060880  -0.123914   0.081516  -0.041027   0.040942
# gender                -0.033180   0.083192  -0.135904   0.050421   0.089404
# spsrq_1               -0.025308   0.014703  -0.050428  -0.097051  -0.020757
# spsrq_2                0.155752   0.036641   0.170300  -0.082270   0.235565
# spsrq_3               -0.004471   0.100228   0.084676  -0.227469   0.038425
# ...                         ...        ...        ...        ...        ...
# bisbas_20              0.187881   0.491711  -0.103453  -0.177646   0.140050
# SPSRWD                 0.404496   0.227954   0.348437   0.082681   0.249105
# BISBAS_BAS             0.604828   0.271536   0.429180   0.179913   0.427269
# BISBAS_BAS_Quintiles   0.578246   0.224598   0.370538   0.164677   0.429809
# SPSRWD_Quintiles       0.370865   0.251654   0.356772   0.092229   0.248656
#
#                       bisbas_20    SPSRWD  BISBAS_BAS  BISBAS_BAS_Quintiles  \
# RealID                -0.016200 -0.041490    0.045425             -0.023076
# gender                 0.038487  0.207568   -0.008792              0.039161
# spsrq_1                0.058878 -0.245142   -0.161618             -0.142898
# spsrq_2                0.094131  0.295153    0.324326              0.312337
# spsrq_3                0.145067 -0.055808    0.026565             -0.032182
# ...                         ...       ...         ...                   ...
# bisbas_20              1.000000  0.088084    0.043721              0.058840
# SPSRWD                 0.088084  1.000000    0.632911              0.674339
# BISBAS_BAS             0.043721  0.632911    1.000000              0.919210
# BISBAS_BAS_Quintiles   0.058840  0.674339    0.919210              1.000000
# SPSRWD_Quintiles       0.091336  0.963316    0.608209              0.671582
#
#                       SPSRWD_Quintiles
# RealID                       -0.052482
# gender                        0.269254
# spsrq_1                      -0.211937
# spsrq_2                       0.283232
# spsrq_3                      -0.047915
# ...                                ...
# bisbas_20                     0.091336
# SPSRWD                        0.963316
# BISBAS_BAS                    0.608209
# BISBAS_BAS_Quintiles          0.671582
# SPSRWD_Quintiles              1.000000
#
# [68 rows x 68 columns]
# <AxesSubplot:>

# %%
df=df[['RealID','gender','SPSRWD','BISBAS_BAS']]
r,p=stats.pearsonr(df['SPSRWD'],df['BISBAS_BAS'])
print("Correlation between reward sensitivity is \n R^2: %s p: %s"%(r**2,p))
g=sms.lmplot(x='SPSRWD',y='BISBAS_BAS',data=df)
plt.show()
print(type(g))
# Out:
# Correlation between reward sensitivity is
#  R^2: 0.4005757191048226 p: 2.8445206641786736e-11
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=1)

features=['SPSRWD','BISBAS_BAS']
X = df.loc[:, features].values
PC1=pca.fit_transform(X)
print(PC1)

df['PC1']=PC1
display(df['PC1'])
df.to_csv(fname,index='False')
# Out:
# [[  0.74861898]
#  [ -1.33873221]
#  [  0.91155464]
#  [  1.17580104]
#  [  1.17580104]
#  [  0.25981198]
#  [ -1.63379108]
#  [ -1.63379108]
#  [ -0.39193069]
#  [ -2.61140508]
#  [  0.71780651]
#  [ -2.25472128]
#  [  1.17580104]
#  [ -9.11576591]
#  [  3.98539316]
#  [ -1.47085541]
#  [ -5.06431339]
#  [  2.5805971 ]
#  [ -3.65951733]
#  [  9.6045774 ]
#  [  1.79673124]
#  [  6.79498528]
#  [ -2.25472128]
#  [ 11.46662854]
#  [ -0.22899502]
#  [ 10.87725026]
#  [ -4.4433832 ]
#  [  1.9596669 ]
#  [ -3.822453  ]
#  [  8.851524  ]
#  [ -4.28044753]
#  [  2.74353277]
#  [  1.17580104]
#  [  1.33873671]
#  [ -2.09178561]
#  [-13.58922437]
#  [  3.2015273 ]
#  [ -1.47085541]
#  [  3.65952183]
#  [ -8.00602871]
#  [ -5.68524359]
#  [  1.33873671]
#  [ -3.65951733]
#  [ -7.57884665]
#  [  3.98539316]
#  [ -0.84992522]
#  [ -3.49658167]
#  [  3.98539316]
#  [ -6.63204512]
#  [ -3.333646  ]
#  [ 11.17230912]
#  [ -1.01286088]
#  [ -0.84992522]
#  [  1.50167237]
#  [  3.2015273 ]
#  [  7.57885114]
#  [ -1.01286088]
#  [  8.65777587]
#  [ -3.2015228 ]
#  [ -3.03858714]
#  [ -2.25472128]
#  [ -1.01286088]
#  [  1.50167237]
#  [  9.79832553]
#  [  4.76925902]
#  [ -9.89963177]
#  [ 14.30777257]
#  [ -5.52230792]
#  [ -3.49658167]
#  [ -7.41591098]
#  [  4.31126449]
#  [ -6.46910945]
#  [ -4.68540201]
#  [ -2.71271581]
#  [  0.88074218]
#  [ 13.36097105]
#  [  5.84818375]
#  [ -1.63379108]
#  [  4.31126449]
#  [ -3.65951733]
#  [  0.71780651]
#  [ -5.68524359]
#  [  1.17580104]
#  [  6.66286208]
#  [ -7.25297532]
#  [ -2.41765694]
#  [  2.74353277]
#  [ -5.52230792]
#  [ -8.65777138]]
# 0     0.748619
# 1    -1.338732
# 2     0.911555
# 3     1.175801
# 4     1.175801
#         ...
# 84   -7.252975
# 85   -2.417657
# 86    2.743533
# 87   -5.522308
# 88   -8.657771
# Name: PC1, Length: 89, dtype: float64

# %%
plt.scatter(X[:, 0], X[:, 1], alpha=0.3, label="samples")
for i, (comp, var) in enumerate(zip(pca.components_, pca.explained_variance_)):
    comp = comp * var  # scale component by its variance explanation power
    plt.plot(
        [0, comp[0]],
        [0, comp[1]],
        label=f"Component {i}",
        linewidth=5,
        color=f"C{i + 2}",
    )
plt.gca().set(
    title="2-dimensional dataset with principal components",
    xlabel="first feature",
    ylabel="second feature",
)
plt.legend()
plt.show()
