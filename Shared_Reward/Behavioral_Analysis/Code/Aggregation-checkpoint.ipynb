# %%
import os
import numpy as np
import pandas as pd
import re

os.chdir('.')

def listdir():
    for root, dirs, files in os.walk("."):
        for filename in files:
            print(filename)

# %%
data = pd.read_csv('SR_PartnerRatings_PS.csv', header = 0)
data
# Out:
#      TrialNumber  Partner  Trait  ran  order  Rating   sub
# 0              1        3      0    1      0       5  1294
# 1              2        2      0    1      1       0  1294
# 2              3        1      0    1      2       0  1294
# 3              4        3      1    1      3      -2  1294
# 4              5        2      1    1      4       0  1294
# ..           ...      ...    ...  ...    ...     ...   ...
# 265            2        2      0    1      1      -2  1001
# 266            3        1      0    1      2       5  1001
# 267            4        3      1    1      3       5  1001
# 268            5        2      1    1      4       0  1001
# 269            6        1      1    1      5       4  1001
#
# [270 rows x 7 columns]

# %%
Trait = {0:'Win', 1:'Lose'}
Partner = {3:'Friend',2:'Stranger',1:'Comp'}

# %%
collapsed = {}
for index, row in data.iterrows():
    if(not row['sub'] in collapsed):
        collapsed[row['sub']] = {}
    column_name = Trait[row['Trait']] + '-' + Partner[row['Partner']]
    collapsed[row['sub']][column_name] = row['Rating']
# Out:
# {1294: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': -2,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1002: {'Win-Friend': 4,
#   'Win-Stranger': 2,
#   'Win-Comp': 0,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 0},
#  1302: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -5,
#   'Lose-Friend': -2,
#   'Lose-Stranger': -3,
#   'Lose-Comp': -5},
#  1244: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 0,
#   'Lose-Friend': -2,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3164: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -2,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -2},
#  1015: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 0,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -3,
#   'Lose-Comp': 0},
#  1009: {'Win-Friend': 5,
#   'Win-Stranger': 4,
#   'Win-Comp': 4,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -4,
#   'Lose-Comp': -4},
#  1006: {'Win-Friend': 3,
#   'Win-Stranger': 2,
#   'Win-Comp': 5,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -1,
#   'Lose-Comp': -2},
#  1282: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 1,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -2,
#   'Lose-Comp': 0},
#  3122: {'Win-Friend': 4,
#   'Win-Stranger': 3,
#   'Win-Comp': 0,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -4,
#   'Lose-Comp': -1},
#  1276: {'Win-Friend': 3,
#   'Win-Stranger': -4,
#   'Win-Comp': 2,
#   'Lose-Friend': -4,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -2},
#  3176: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 2,
#   'Lose-Friend': -1,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -3},
#  1243: {'Win-Friend': 2,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': -2,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 0},
#  1012: {'Win-Friend': 3,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': -3,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3116: {'Win-Friend': 5,
#   'Win-Stranger': 1,
#   'Win-Comp': 0,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 0},
#  3143: {'Win-Friend': 4,
#   'Win-Stranger': -2,
#   'Win-Comp': 3,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -2},
#  1016: {'Win-Friend': 0,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3190: {'Win-Friend': 5,
#   'Win-Stranger': -1,
#   'Win-Comp': 4,
#   'Lose-Friend': 2,
#   'Lose-Stranger': -2,
#   'Lose-Comp': 2},
#  3186: {'Win-Friend': 4,
#   'Win-Stranger': 0,
#   'Win-Comp': -2,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -1,
#   'Lose-Comp': 4},
#  3166: {'Win-Friend': 4,
#   'Win-Stranger': 1,
#   'Win-Comp': 0,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -3,
#   'Lose-Comp': -1},
#  3125: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -5,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1021: {'Win-Friend': 1,
#   'Win-Stranger': 1,
#   'Win-Comp': 0,
#   'Lose-Friend': 1,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3167: {'Win-Friend': 5,
#   'Win-Stranger': 3,
#   'Win-Comp': 2,
#   'Lose-Friend': -2,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -3},
#  1300: {'Win-Friend': 3,
#   'Win-Stranger': 5,
#   'Win-Comp': 0,
#   'Lose-Friend': -1,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1301: {'Win-Friend': -1,
#   'Win-Stranger': -2,
#   'Win-Comp': 3,
#   'Lose-Friend': -3,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  3189: {'Win-Friend': 3,
#   'Win-Stranger': 2,
#   'Win-Comp': 1,
#   'Lose-Friend': -4,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -1},
#  1007: {'Win-Friend': 4,
#   'Win-Stranger': 4,
#   'Win-Comp': 3,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1011: {'Win-Friend': 5,
#   'Win-Stranger': 5,
#   'Win-Comp': 2,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -5},
#  1013: {'Win-Friend': 5,
#   'Win-Stranger': -3,
#   'Win-Comp': 2,
#   'Lose-Friend': -4,
#   'Lose-Stranger': 1,
#   'Lose-Comp': -2},
#  3173: {'Win-Friend': 5,
#   'Win-Stranger': -2,
#   'Win-Comp': -4,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1242: {'Win-Friend': 0,
#   'Win-Stranger': 0,
#   'Win-Comp': 0,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1249: {'Win-Friend': 5,
#   'Win-Stranger': 5,
#   'Win-Comp': 4,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -4},
#  1019: {'Win-Friend': 5,
#   'Win-Stranger': 2,
#   'Win-Comp': 0,
#   'Lose-Friend': -3,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1248: {'Win-Friend': 1,
#   'Win-Stranger': 0,
#   'Win-Comp': -5,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -5,
#   'Lose-Comp': -5},
#  3170: {'Win-Friend': 5,
#   'Win-Stranger': 4,
#   'Win-Comp': 3,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 0},
#  1286: {'Win-Friend': 4,
#   'Win-Stranger': 2,
#   'Win-Comp': 3,
#   'Lose-Friend': -3,
#   'Lose-Stranger': -2,
#   'Lose-Comp': -3},
#  3152: {'Win-Friend': 5,
#   'Win-Stranger': 2,
#   'Win-Comp': 3,
#   'Lose-Friend': -5,
#   'Lose-Stranger': -1,
#   'Lose-Comp': -3},
#  1010: {'Win-Friend': 1,
#   'Win-Stranger': -2,
#   'Win-Comp': -5,
#   'Lose-Friend': 2,
#   'Lose-Stranger': -3,
#   'Lose-Comp': -5},
#  1255: {'Win-Friend': 5,
#   'Win-Stranger': 0,
#   'Win-Comp': -1,
#   'Lose-Friend': -5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -2},
#  3140: {'Win-Friend': 5,
#   'Win-Stranger': 2,
#   'Win-Comp': -1,
#   'Lose-Friend': -2,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -1},
#  1251: {'Win-Friend': 2,
#   'Win-Stranger': 0,
#   'Win-Comp': 1,
#   'Lose-Friend': 0,
#   'Lose-Stranger': 0,
#   'Lose-Comp': -2},
#  1001: {'Win-Friend': 5,
#   'Win-Stranger': -2,
#   'Win-Comp': 5,
#   'Lose-Friend': 5,
#   'Lose-Stranger': 0,
#   'Lose-Comp': 4}}

# %%
#PR = Partner Ratings from post-scan task
PR = pd.DataFrame(collapsed).T
PR = PR.reset_index().rename(columns = {'index':'sub'})
PR.to_csv('SR_PartnerRatings.csv',index=False)
pd.read_csv('SR_PartnerRatings.csv')
# Out:
#      sub  Win-Friend  Win-Stranger  Win-Comp  Lose-Friend  Lose-Stranger  \
# 0   1294           5             0         0           -2              0
# 1   1002           4             2         0           -3             -1
# 2   1302           5             0        -5           -2             -3
# 3   1244           5             3         0           -2              0
# 4   3164           5             0        -2           -4             -5
# 5   1015           5             3         0           -5             -3
# 6   1009           5             4         4           -5             -4
# 7   1006           3             2         5           -4             -1
# 8   1282           5             3         1           -4             -2
# 9   3122           4             3         0           -5             -4
# 10  1276           3            -4         2           -4              0
# 11  3176           5             3         2           -1             -2
# 12  1243           2             0         0           -2             -1
# 13  1012           3             0         0           -3              0
# 14  3116           5             1         0           -4             -1
# 15  3143           4            -2         3           -5             -2
# 16  1016           0             0         0            0              0
# 17  3190           5            -1         4            2             -2
# 18  3186           4             0        -2           -3             -1
# 19  3166           4             1         0           -5             -3
# 20  3125           5             0        -5           -5              0
# 21  1021           1             1         0            1              0
# 22  3167           5             3         2           -2             -5
# 23  1300           3             5         0           -1              0
# 24  1301          -1            -2         3           -3              0
# 25  3189           3             2         1           -4             -2
# 26  1007           4             4         3            0              0
# 27  1011           5             5         2           -5             -5
# 28  1013           5            -3         2           -4              1
# 29  3173           5            -2        -4           -5              0
# 30  1242           0             0         0            0              0
# 31  1249           5             5         4           -5             -5
# 32  1019           5             2         0           -3              0
# 33  1248           1             0        -5           -3             -5
# 34  3170           5             4         3           -5              0
# 35  1286           4             2         3           -3             -2
# 36  3152           5             2         3           -5             -1
# 37  1010           1            -2        -5            2             -3
# 38  1255           5             0        -1           -5              0
# 39  3140           5             2        -1           -2              0
# 40  1251           2             0         1            0              0
# 41  1001           5            -2         5            5              0
#
#     Lose-Comp
# 0           0
# 1           0
# 2          -5
# 3           0
# 4          -2
# 5           0
# 6          -4
# 7          -2
# 8           0
# 9          -1
# 10         -2
# 11         -3
# 12          0
# 13          0
# 14          0
# 15         -2
# 16          0
# 17          2
# 18          4
# 19         -1
# 20          0
# 21          0
# 22         -3
# 23          0
# 24          0
# 25         -1
# 26          0
# 27         -5
# 28         -2
# 29          0
# 30          0
# 31         -4
# 32          0
# 33         -5
# 34          0
# 35         -3
# 36         -3
# 37         -5
# 38         -2
# 39         -1
# 40         -2
# 41          4

# %%
#RC = REDCap data
RC = pd.read_csv('SR_REDCap_data.csv').rename(columns = {'participant_ID':'sub'})
#RS = Reward Sensitivity scores
RS = pd.read_csv('Reward_Sensitivity.csv').rename(columns = {'RealID':'sub'})
#ARSD = All Reward Sensitivity Data
RS = RS.merge(PR, on = 'sub', how = 'right').sort_values('sub', ascending = True, ignore_index = True)
ARSD = RS.merge(RC, on = 'sub', how = 'left').sort_values('sub', ascending = True, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-c2e00ce53137> in <module>
#       5 #ARSD = All Reward Sensitivity Data
#       6 RS = RS.merge(PR, on = 'sub', how = 'right').sort_values('sub', ascending = True, ignore_index = True)
# ----> 7 ARSD = RS.merge(RC, on = 'sub', how = 'left').sort_values('sub', ascending = True, ignore_index = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1031                     if not is_rkey(rk):
#    1032                         if rk is not None:
# -> 1033                             right_keys.append(right._get_label_or_level_values(rk))
#    1034                         else:
#    1035                             # work-around for merge_asof(right_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'sub'
